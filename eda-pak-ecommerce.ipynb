# %% [markdown]
# # <b>EDA on Pakistan's Largest E-Commerce Dataset

# %% [markdown]
# ### <b> About Dataset </b>
# This is the largest retail e-commerce orders dataset from Pakistan. It contains half a million transaction records from March 2016 to August 2018. The data was collected from various e-commerce merchants as part of a research study.
#
# ### <b> Content </b>
# <b>Geography:</b> Pakistan
#
# <b>Time period:</b> 03/2016 – 08/2018
#
# <b>Unit of analysis:</b> E-Commerce Orders
#
# <b>Dataset:</b> The dataset contains detailed information of half a million e-commerce orders in Pakistan from March 2016 to August 2018. It contains item details, shipping method, payment method like credit card, Easy-Paisa, Jazz-Cash, cash-on-delivery, product categories like fashion, mobile, electronics, appliance etc., date of order, SKU, price, quantity, total and customer ID. This is the most detailed dataset about e-commerce in Pakistan that you can find in the Public domain.
#
# <b>Variables:</b> The dataset contains
# - Item ID
# - Order Status (Completed, Cancelled, Refund)
# - Date of Order
# - SKU, Price
# - Quantity
# - Grand Total
# - Category
# - Payment Method
# - Customer ID.

# %% [markdown]
# # Problem Statement

# %% [markdown]
# A group of entrepreuners want to start a new E-Commerce business in Pakistan. They have gathered the data of half a million e-commerce orders in Pakistan from March 2016 to August 2018. Now as a data analyst, you have to analyze and explore the data to find out useful insights, answer various analytical and research questions and test different hypothesis with data driven approach, so that entreprueners can take informed decisions after looking what the data says?
#
# Your responsiblities includes:
# - Optimizing the Launch of a New E-commerce Business in Pakistan
# - Optimizing it's Operations for Improved Customer Satisfaction and Profitability

# %% [markdown]
# # Assumptions before starting
# - The dataset is still valid as of 2024 and can used to analyze in an efficient manner.

# %% [markdown]
# # Analytical and research questions

# %% [markdown]
# - What is the best-selling product categories among Pakistani online shoppers?
# - Sale trends of previous years, in which months there are high sales?
# - How does the choice of payment method (credit card, Easy-Paisa, Jazz-Cash, cash-on-delivery) influence the completion and satisfaction of e-commerce orders?

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Loading dataset

# %%
pak_ecommerce_data = pd.read_csv('./datasets/Pakistan Largest Ecommerce Dataset.csv', low_memory=False)

# %% [markdown]
# # Data identification and cleaning

# %%
pak_ecommerce_data.head(10)
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete   7/1/2016
# 1  211133.0        canceled   7/1/2016
# 2  211134.0        canceled   7/1/2016
# 3  211135.0        complete   7/1/2016
# 4  211136.0  order_refunded   7/1/2016
# 5  211137.0        canceled   7/1/2016
# 6  211138.0        complete   7/1/2016
# 7  211139.0        complete   7/1/2016
# 8  211140.0        canceled   7/1/2016
# 9  211141.0        canceled   7/1/2016
#
#                                                  sku    price  qty_ordered  \
# 0                                  kreations_YI 06-L   1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...    240.0          1.0
# 2                                 Ego_UP0017-999-MR0   2450.0          1.0
# 3                                     kcc_krone deal    360.0          1.0
# 4                                        BK7010400AG    555.0          2.0
# 5                      UK_Namkino All In One 200 Gms     80.0          1.0
# 6                                     kcc_krone deal    360.0          1.0
# 7                       UK_Namkino Mix Nimco 400 Gms    170.0          1.0
# 8                               Apple iPhone 6S 64GB  96499.0          1.0
# 9                               Apple iPhone 6S 64GB  96499.0          1.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# 2       2450.0    100147445    Women's Fashion                    \N  ...
# 3         60.0    100147446  Beauty & Grooming           R-FSD-52352  ...
# 4       1110.0    100147447            Soghaat                    \N  ...
# 5         80.0    100147448            Soghaat                    \N  ...
# 6         60.0    100147449  Beauty & Grooming                    \N  ...
# 7        170.0    100147450            Soghaat                    \N  ...
# 8      96499.0    100147451  Mobiles & Tablets                    \N  ...
# 9      96499.0    100147452  Mobiles & Tablets                    \N  ...
#
#    Month Customer Since     M-Y    FY Customer ID  Unnamed: 21  Unnamed: 22  \
# 0    7.0         2016-7  7-2016  FY17         1.0          NaN          NaN
# 1    7.0         2016-7  7-2016  FY17         2.0          NaN          NaN
# 2    7.0         2016-7  7-2016  FY17         3.0          NaN          NaN
# 3    7.0         2016-7  7-2016  FY17         4.0          NaN          NaN
# 4    7.0         2016-7  7-2016  FY17         5.0          NaN          NaN
# 5    7.0         2016-7  7-2016  FY17         6.0          NaN          NaN
# 6    7.0         2016-7  7-2016  FY17         7.0          NaN          NaN
# 7    7.0         2016-7  7-2016  FY17         6.0          NaN          NaN
# 8    7.0         2016-7  7-2016  FY17         8.0          NaN          NaN
# 9    7.0         2016-7  7-2016  FY17         8.0          NaN          NaN
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
# 5         NaN         NaN         NaN
# 6         NaN         NaN         NaN
# 7         NaN         NaN         NaN
# 8         NaN         NaN         NaN
# 9         NaN         NaN         NaN
#
# [10 rows x 26 columns]

# %%
pak_ecommerce_data.tail(10)
# Out:
#          item_id status created_at  sku  price  qty_ordered  grand_total  \
# 1048565      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048566      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048567      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048568      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048569      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048570      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048571      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048572      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048573      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048574      NaN    NaN        NaN  NaN    NaN          NaN          NaN
#
#         increment_id category_name_1 sales_commission_code  ...  Month  \
# 1048565          NaN             NaN                   NaN  ...    NaN
# 1048566          NaN             NaN                   NaN  ...    NaN
# 1048567          NaN             NaN                   NaN  ...    NaN
# 1048568          NaN             NaN                   NaN  ...    NaN
# 1048569          NaN             NaN                   NaN  ...    NaN
# 1048570          NaN             NaN                   NaN  ...    NaN
# 1048571          NaN             NaN                   NaN  ...    NaN
# 1048572          NaN             NaN                   NaN  ...    NaN
# 1048573          NaN             NaN                   NaN  ...    NaN
# 1048574          NaN             NaN                   NaN  ...    NaN
#
#         Customer Since  M-Y   FY Customer ID  Unnamed: 21  Unnamed: 22  \
# 1048565            NaN  NaN  NaN         NaN          NaN          NaN
# 1048566            NaN  NaN  NaN         NaN          NaN          NaN
# 1048567            NaN  NaN  NaN         NaN          NaN          NaN
# 1048568            NaN  NaN  NaN         NaN          NaN          NaN
# 1048569            NaN  NaN  NaN         NaN          NaN          NaN
# 1048570            NaN  NaN  NaN         NaN          NaN          NaN
# 1048571            NaN  NaN  NaN         NaN          NaN          NaN
# 1048572            NaN  NaN  NaN         NaN          NaN          NaN
# 1048573            NaN  NaN  NaN         NaN          NaN          NaN
# 1048574            NaN  NaN  NaN         NaN          NaN          NaN
#
#         Unnamed: 23 Unnamed: 24 Unnamed: 25
# 1048565         NaN         NaN         NaN
# 1048566         NaN         NaN         NaN
# 1048567         NaN         NaN         NaN
# 1048568         NaN         NaN         NaN
# 1048569         NaN         NaN         NaN
# 1048570         NaN         NaN         NaN
# 1048571         NaN         NaN         NaN
# 1048572         NaN         NaN         NaN
# 1048573         NaN         NaN         NaN
# 1048574         NaN         NaN         NaN
#
# [10 rows x 26 columns]

# %%
pak_ecommerce_data.shape
# Out:
# (1048575, 26)

# %%
pak_ecommerce_data.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', ' MV ', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
pak_ecommerce_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  float64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  float64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
#  9   sales_commission_code  447346 non-null  object
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  object
#  12  Working Date           584524 non-null  object
#  13  BI Status              584524 non-null  object
#  14   MV                    584524 non-null  object
#  15  Year                   584524 non-null  float64
#  16  Month                  584524 non-null  float64
#  17  Customer Since         584513 non-null  object
#  18  M-Y                    584524 non-null  object
#  19  FY                     584524 non-null  object
#  20  Customer ID            584513 non-null  float64
#  21  Unnamed: 21            0 non-null       float64
#  22  Unnamed: 22            0 non-null       float64
#  23  Unnamed: 23            0 non-null       float64
#  24  Unnamed: 24            0 non-null       float64
#  25  Unnamed: 25            0 non-null       float64
# dtypes: float64(13), object(13)
# memory usage: 208.0+ MB

# %% [markdown]
# ### Handling null/irrelevant values and columns

# %%
# Checking for null values
pak_ecommerce_data.isna().sum()
# Out:
# item_id                   464051
# status                    464066
# created_at                464051
# sku                       464071
# price                     464051
# qty_ordered               464051
# grand_total               464051
# increment_id              464051
# category_name_1           464215
# sales_commission_code     601229
# discount_amount           464051
# payment_method            464051
# Working Date              464051
# BI Status                 464051
#  MV                       464051
# Year                      464051
# Month                     464051
# Customer Since            464062
# M-Y                       464051
# FY                        464051
# Customer ID               464062
# Unnamed: 21              1048575
# Unnamed: 22              1048575
# Unnamed: 23              1048575
# Unnamed: 24              1048575
# Unnamed: 25              1048575
# dtype: int64

# %%
# Dropping null columns(last 5)
pak_ecommerce_data = pak_ecommerce_data.iloc[:, :-5]

pak_ecommerce_data.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', ' MV ', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID'],
#       dtype='object')

# %%
# Now dropping null rows
pak_ecommerce_data[pak_ecommerce_data['item_id'].isna()]
# Out:
#          item_id status created_at  sku  price  qty_ordered  grand_total  \
# 584524       NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 584525       NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 584526       NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 584527       NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 584528       NaN    NaN        NaN  NaN    NaN          NaN          NaN
# ...          ...    ...        ...  ...    ...          ...          ...
# 1048570      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048571      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048572      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048573      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048574      NaN    NaN        NaN  NaN    NaN          NaN          NaN
#
#         increment_id category_name_1 sales_commission_code  ...  \
# 584524           NaN             NaN                   NaN  ...
# 584525           NaN             NaN                   NaN  ...
# 584526           NaN             NaN                   NaN  ...
# 584527           NaN             NaN                   NaN  ...
# 584528           NaN             NaN                   NaN  ...
# ...              ...             ...                   ...  ...
# 1048570          NaN             NaN                   NaN  ...
# 1048571          NaN             NaN                   NaN  ...
# 1048572          NaN             NaN                   NaN  ...
# 1048573          NaN             NaN                   NaN  ...
# 1048574          NaN             NaN                   NaN  ...
#
#          payment_method Working Date BI Status  MV  Year  Month  \
# 584524              NaN          NaN       NaN  NaN  NaN    NaN
# 584525              NaN          NaN       NaN  NaN  NaN    NaN
# 584526              NaN          NaN       NaN  NaN  NaN    NaN
# 584527              NaN          NaN       NaN  NaN  NaN    NaN
# 584528              NaN          NaN       NaN  NaN  NaN    NaN
# ...                 ...          ...       ...  ...  ...    ...
# 1048570             NaN          NaN       NaN  NaN  NaN    NaN
# 1048571             NaN          NaN       NaN  NaN  NaN    NaN
# 1048572             NaN          NaN       NaN  NaN  NaN    NaN
# 1048573             NaN          NaN       NaN  NaN  NaN    NaN
# 1048574             NaN          NaN       NaN  NaN  NaN    NaN
#
#          Customer Since  M-Y   FY Customer ID
# 584524              NaN  NaN  NaN         NaN
# 584525              NaN  NaN  NaN         NaN
# 584526              NaN  NaN  NaN         NaN
# 584527              NaN  NaN  NaN         NaN
# 584528              NaN  NaN  NaN         NaN
# ...                 ...  ...  ...         ...
# 1048570             NaN  NaN  NaN         NaN
# 1048571             NaN  NaN  NaN         NaN
# 1048572             NaN  NaN  NaN         NaN
# 1048573             NaN  NaN  NaN         NaN
# 1048574             NaN  NaN  NaN         NaN
#
# [464051 rows x 21 columns]

# %%
pak_ecommerce_data.dropna(subset=['item_id'], inplace=True)

pak_ecommerce_data.head(2)
# Out:
#     item_id    status created_at  \
# 0  211131.0  complete   7/1/2016
# 1  211133.0  canceled   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
#
#    payment_method Working Date BI Status      MV     Year  Month  \
# 0             cod     7/1/2016     #REF!   1,950   2016.0    7.0
# 1             cod     7/1/2016     Gross     240   2016.0    7.0
#
#    Customer Since     M-Y    FY Customer ID
# 0          2016-7  7-2016  FY17         1.0
# 1          2016-7  7-2016  FY17         2.0
#
# [2 rows x 21 columns]

# %%
pak_ecommerce_data.isna().sum()
# Out:
# item_id                       0
# status                       15
# created_at                    0
# sku                          20
# price                         0
# qty_ordered                   0
# grand_total                   0
# increment_id                  0
# category_name_1             164
# sales_commission_code    137178
# discount_amount               0
# payment_method                0
# Working Date                  0
# BI Status                     0
#  MV                           0
# Year                          0
# Month                         0
# Customer Since               11
# M-Y                           0
# FY                            0
# Customer ID                  11
# dtype: int64

# %%
# Converting date columns to date-time format
pak_ecommerce_data['created_at'] = pd.to_datetime(pak_ecommerce_data['created_at'])
pak_ecommerce_data['Working Date'] = pd.to_datetime(pak_ecommerce_data['Working Date'])

# %%
summary_stats_categorical = pak_ecommerce_data.describe(include='object')
summary_stats_categorical
# Out:
#           status                  sku increment_id    category_name_1  \
# count     584509               584504       584524             584360
# unique        16                84889       408782                 16
# top     complete  MATSAM59DB75ADB2F80    100266667  Mobiles & Tablets
# freq      233685                 3775           72             115710
#
#        sales_commission_code payment_method BI Status     MV  Customer Since  \
# count                 447346         584524    584524  584524         584513
# unique                  7225             18         4    9720             26
# top                       \N            cod       Net    999         2016-11
# freq                  339001         271960    234178    9516          82714
#
#             M-Y      FY
# count    584524  584524
# unique       26       3
# top     11-2017    FY18
# freq      83928  306883

# %%
for col in summary_stats_categorical.columns:
    print(col)
    print(pak_ecommerce_data[col].unique())
    print('_'*50)
# Out:
# status
# ['complete' 'canceled' 'order_refunded' 'received' 'refund' 'closed'
#  'fraud' 'holded' 'exchange' 'pending_paypal' 'paid' '\\N' 'cod' 'pending'
#  nan 'processing' 'payment_review']
# __________________________________________________
# sku
# ['kreations_YI 06-L'
#  'kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Body Spray Free'
#  'Ego_UP0017-999-MR0' ... 'WOFVAL59D5EA84167F9-M' 'WOFNIG5B4D7EB0E9FDD-L'
#  'WOFSCE5AE00357AECDE']
# __________________________________________________
# increment_id
# ['100147443' '100147444' '100147445' ... '100562385' '100562386'
#  '100562387']
# __________________________________________________
# category_name_1
# ["Women's Fashion" 'Beauty & Grooming' 'Soghaat' 'Mobiles & Tablets'
#  'Appliances' 'Home & Living' "Men's Fashion" 'Kids & Baby' '\\N' 'Others'
#  'Entertainment' 'Computing' 'Superstore' 'Health & Sports' 'Books'
#  'School & Education' nan]
# __________________________________________________
# sales_commission_code
# ['\\N' 'R-FSD-52352' '105259' ... 'GRS-4090974-1' 'GRS-4090975-1'
#  '100559728']
# __________________________________________________
# payment_method
# ['cod' 'ublcreditcard' 'mygateway' 'customercredit' 'cashatdoorstep'
#  'mcblite' 'internetbanking' 'marketingexpense' 'productcredit'
#  'financesettlement' 'Payaxis' 'jazzvoucher' 'jazzwallet' 'Easypay'
#  'Easypay_MA' 'easypay_voucher' 'bankalfalah' 'apg']
# __________________________________________________
# BI Status
# ['#REF!' 'Gross' 'Net' 'Valid']
# __________________________________________________
#  MV
# [' 1,950 ' ' 240 ' ' 2,450 ' ... ' 70,894 ' ' 8,165 ' ' 8,344 ']
# __________________________________________________
# Customer Since
# ['2016-7' '2016-8' '2016-9' '2016-10' '2016-11' '2016-12' '2017-1'
#  '2017-2' '2017-3' '2017-4' '2017-5' '2017-6' '2017-7' '2017-8' '2017-9'
#  '2017-10' '2017-11' '2017-12' '2018-1' nan '2018-2' '2018-3' '2018-4'
#  '2018-5' '2018-6' '2018-7' '2018-8']
# __________________________________________________
# M-Y
# ['7-2016' '8-2016' '9-2016' '10-2016' '11-2016' '12-2016' '1-2017'
#  '2-2017' '3-2017' '4-2017' '5-2017' '6-2017' '7-2017' '8-2017' '9-2017'
#  '10-2017' '11-2017' '12-2017' '2-2018' '1-2018' '3-2018' '4-2018'
#  '5-2018' '6-2018' '7-2018' '8-2018']
# __________________________________________________
# FY
# ['FY17' 'FY18' 'FY19']
# __________________________________________________

# %%
pak_ecommerce_data.drop(columns=['increment_id', 'sales_commission_code', 'FY', 'M-Y', 'BI Status', ' MV '], inplace=True)

# %%
pak_ecommerce_data.head()
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete 2016-07-01
# 1  211133.0        canceled 2016-07-01
# 2  211134.0        canceled 2016-07-01
# 3  211135.0        complete 2016-07-01
# 4  211136.0  order_refunded 2016-07-01
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total    category_name_1  discount_amount payment_method  \
# 0       1950.0    Women's Fashion              0.0            cod
# 1        240.0  Beauty & Grooming              0.0            cod
# 2       2450.0    Women's Fashion              0.0            cod
# 3         60.0  Beauty & Grooming            300.0            cod
# 4       1110.0            Soghaat              0.0            cod
#
#   Working Date    Year  Month Customer Since  Customer ID
# 0   2016-07-01  2016.0    7.0         2016-7          1.0
# 1   2016-07-01  2016.0    7.0         2016-7          2.0
# 2   2016-07-01  2016.0    7.0         2016-7          3.0
# 3   2016-07-01  2016.0    7.0         2016-7          4.0
# 4   2016-07-01  2016.0    7.0         2016-7          5.0

# %%
pak_ecommerce_data.isna().sum()
# Out:
# item_id              0
# status              15
# created_at           0
# sku                 20
# price                0
# qty_ordered          0
# grand_total          0
# category_name_1    164
# discount_amount      0
# payment_method       0
# Working Date         0
# Year                 0
# Month                0
# Customer Since      11
# Customer ID         11
# dtype: int64

# %%
pak_ecommerce_data[pak_ecommerce_data['category_name_1'].isna()]
# Out:
#          item_id          status created_at                    sku  price  \
# 425895  725194.0  order_refunded 2018-01-02  MEFQMO59B0942707B79-L   99.0
# 431194  731122.0        received 2018-01-15  MEFQMO59B0942707B79-M   99.0
# 432492  732569.0        canceled 2018-01-19  MEFQMO59B0942707B79-M   99.0
# 432494  732572.0        canceled 2018-01-19  MEFQMO59B0942707B79-M   99.0
# 432496  732575.0  order_refunded 2018-01-19  MEFQMO59B0942707B79-M   99.0
# ...          ...             ...        ...                    ...    ...
# 535572  850761.0        received 2018-05-16    KABASA5ABC763F62E76  506.0
# 541927  857600.0        received 2018-05-25    WOFASA5AE962A6DD038  199.0
# 549314  865823.0        canceled 2018-06-04  MEFQMO59B0942707B79-M   99.0
# 568069  886699.0        canceled 2018-07-18     COMWD5AA8FF5851E73  314.0
# 580564  900744.0        received 2018-08-15     COMWD5AA8FF5851E73  314.0
#
#         qty_ordered  grand_total category_name_1  discount_amount  \
# 425895          2.0          2.0             NaN            346.0
# 431194          1.0        249.0             NaN              0.0
# 432492          1.0        249.0             NaN              0.0
# 432494          1.0        249.0             NaN              0.0
# 432496          1.0        249.0             NaN              0.0
# ...             ...          ...             ...              ...
# 535572          1.0        656.0             NaN              0.0
# 541927          1.0       1344.0             NaN              0.0
# 549314          1.0        249.0             NaN              0.0
# 568069          1.0        464.0             NaN              0.0
# 580564          1.0       4785.0             NaN              0.0
#
#          payment_method Working Date    Year  Month Customer Since  \
# 425895          Easypay   2018-01-02  2018.0    1.0         2017-8
# 431194              cod   2018-01-15  2018.0    1.0         2017-8
# 432492      bankalfalah   2018-01-19  2018.0    1.0         2017-3
# 432494      bankalfalah   2018-01-19  2018.0    1.0         2017-3
# 432496              cod   2018-01-19  2018.0    1.0         2018-1
# ...                 ...          ...     ...    ...            ...
# 535572              cod   2018-05-16  2018.0    5.0         2018-5
# 541927              cod   2018-05-25  2018.0    5.0         2016-7
# 549314          Easypay   2018-06-04  2018.0    6.0         2018-1
# 568069  easypay_voucher   2018-07-18  2018.0    7.0         2018-7
# 580564              cod   2018-08-15  2018.0    8.0        2017-11
#
#         Customer ID
# 425895      59587.0
# 431194      59587.0
# 432492      37311.0
# 432494      37311.0
# 432496      85633.0
# ...             ...
# 535572     108622.0
# 541927       2237.0
# 549314      85385.0
# 568069     113144.0
# 580564      79853.0
#
# [164 rows x 15 columns]

# %%
pak_ecommerce_data['category_name_1'].fillna('Others', inplace=True)

# %%
pak_ecommerce_data.isna().sum()
# Out:
# item_id             0
# status             15
# created_at          0
# sku                20
# price               0
# qty_ordered         0
# grand_total         0
# category_name_1     0
# discount_amount     0
# payment_method      0
# Working Date        0
# Year                0
# Month               0
# Customer Since     11
# Customer ID        11
# dtype: int64

# %%
pak_ecommerce_data[pak_ecommerce_data['status'].isna()].head()
# Out:
#          item_id status created_at                              sku   price  \
# 477519  783751.0    NaN 2018-03-15              OTHPCB5A7D8A0BD10E8  8000.0
# 513736  827187.0    NaN 2018-04-16           KABOXF5ABCC75C7E2F7-32   370.0
# 513737  827189.0    NaN 2018-04-16  KABSHO5AA77C331466F-11-13 Years   473.0
# 513738  827191.0    NaN 2018-04-16    KABBIN5A93E074C501A-8-9 Years   749.0
# 513739  827193.0    NaN 2018-04-16  KABLIT59AC117FD51C4-12-13 Years   692.0
#
#         qty_ordered  grand_total category_name_1  discount_amount  \
# 477519          1.0       8000.0          Others              0.0
# 513736          1.0       2707.0     Kids & Baby              0.0
# 513737          1.0       2707.0     Kids & Baby              0.0
# 513738          1.0       2707.0     Kids & Baby              0.0
# 513739          1.0       2707.0     Kids & Baby              0.0
#
#        payment_method Working Date    Year  Month Customer Since  Customer ID
# 477519            cod   2018-03-15  2018.0    3.0         2018-3      95141.0
# 513736            cod   2018-04-16  2018.0    4.0         2018-4     105059.0
# 513737            cod   2018-04-16  2018.0    4.0         2018-4     105059.0
# 513738            cod   2018-04-16  2018.0    4.0         2018-4     105059.0
# 513739            cod   2018-04-16  2018.0    4.0         2018-4     105059.0

# %% [markdown]
# No need to remove remaining null values!

# %%
pak_ecommerce_data.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'category_name_1', 'discount_amount', 'payment_method',
#        'Working Date', 'Year', 'Month', 'Customer Since', 'Customer ID'],
#       dtype='object')

# %%
# Renaming columns in a single format.
pak_ecommerce_data.rename(columns={'Working Date' : 'working_date',
                                   'Year' : 'year', 'Month' : 'month',
                                   'Customer Since': 'customer_since',
                                   'Customer ID' : 'customer_id',
                                   'category_name_1': 'category_name'}, inplace= True)

# %%
#Checking for any duplicate entry
pak_ecommerce_data['item_id'].duplicated().sum()
# Out:
# 0

# %%
pak_ecommerce_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 584524 entries, 0 to 584523
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   item_id          584524 non-null  float64
#  1   status           584509 non-null  object
#  2   created_at       584524 non-null  datetime64[ns]
#  3   sku              584504 non-null  object
#  4   price            584524 non-null  float64
#  5   qty_ordered      584524 non-null  float64
#  6   grand_total      584524 non-null  float64
#  7   category_name    584524 non-null  object
#  8   discount_amount  584524 non-null  float64
#  9   payment_method   584524 non-null  object
#  10  working_date     584524 non-null  datetime64[ns]
#  11  year             584524 non-null  float64
#  12  month            584524 non-null  float64
#  13  customer_since   584513 non-null  object
#  14  customer_id      584513 non-null  float64
# dtypes: datetime64[ns](2), float64(8), object(5)
# memory usage: 71.4+ MB

# %% [markdown]
# Changing some columns data type to string as they are categorical.

# %%
pak_ecommerce_data[['year', 'month', 'customer_id','item_id']] = pak_ecommerce_data[['year', 'month', 'customer_id','item_id']].astype(str)

# %%
pak_ecommerce_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 584524 entries, 0 to 584523
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   item_id          584524 non-null  object
#  1   status           584509 non-null  object
#  2   created_at       584524 non-null  datetime64[ns]
#  3   sku              584504 non-null  object
#  4   price            584524 non-null  float64
#  5   qty_ordered      584524 non-null  float64
#  6   grand_total      584524 non-null  float64
#  7   category_name    584524 non-null  object
#  8   discount_amount  584524 non-null  float64
#  9   payment_method   584524 non-null  object
#  10  working_date     584524 non-null  datetime64[ns]
#  11  year             584524 non-null  object
#  12  month            584524 non-null  object
#  13  customer_since   584513 non-null  object
#  14  customer_id      584524 non-null  object
# dtypes: datetime64[ns](2), float64(4), object(9)
# memory usage: 71.4+ MB

# %% [markdown]
# ### Checking for outliers
# Some outliers represent natural variations in the population, and they should be left as is in your dataset. These are called true outliers. Other outliers are problematic and should be removed because they represent measurement errors, data entry or processing errors, or poor sampling.

# %%
pak_ecommerce_data.describe()
# Out:
#                           created_at         price    qty_ordered  \
# count                         584524  5.845240e+05  584524.000000
# mean   2017-08-08 11:42:53.589450752  6.348748e+03       1.296388
# min              2016-07-01 00:00:00  0.000000e+00       1.000000
# 25%              2017-01-29 00:00:00  3.600000e+02       1.000000
# 50%              2017-08-17 00:00:00  8.990000e+02       1.000000
# 75%              2018-02-03 00:00:00  4.070000e+03       1.000000
# max              2018-08-28 00:00:00  1.012626e+06    1000.000000
# std                              NaN  1.494927e+04       3.996061
#
#         grand_total  discount_amount                   working_date
# count  5.845240e+05    584524.000000                         584524
# mean   8.530619e+03       499.492775  2017-08-08 11:42:53.589450752
# min   -1.594000e+03      -599.500000            2016-07-01 00:00:00
# 25%    9.450000e+02         0.000000            2017-01-29 00:00:00
# 50%    1.960400e+03         0.000000            2017-08-17 00:00:00
# 75%    6.999000e+03       160.500000            2018-02-03 00:00:00
# max    1.788800e+07     90300.000000            2018-08-28 00:00:00
# std    6.132081e+04      1506.943046                            NaN

# %%
pak_ecommerce_data[pak_ecommerce_data['discount_amount'] == 90300]
# Out:
#         item_id    status created_at  \
# 99815  334738.0  complete 2016-11-25
# 99847  334783.0  complete 2016-11-25
#
#                                                      sku     price  \
# 99815  Changhong Ruba 55 Inches UD55D6000i Ultra HD T...  129000.0
# 99847  Changhong Ruba 55 Inches UD55D6000i Ultra HD T...  129000.0
#
#        qty_ordered  grand_total  category_name  discount_amount  \
# 99815          1.0      38700.0  Entertainment          90300.0
# 99847          1.0      38700.0  Entertainment          90300.0
#
#       payment_method working_date    year month customer_since customer_id
# 99815     jazzwallet   2016-11-25  2016.0  11.0         2016-9      9304.0
# 99847        Payaxis   2016-11-25  2016.0  11.0         2016-9      9304.0

# %%
pak_ecommerce_data[pak_ecommerce_data['qty_ordered'] == 1000]
# Out:
#          item_id    status created_at                      sku   price  \
# 239376  507556.0  canceled 2017-06-08       IDROID_BALRX7-Gold  8944.0
# 239377  507557.0  canceled 2017-06-08  IDROID_BALRX7-Jet black  8944.0
# 239381  507561.0  canceled 2017-06-08  IDROID_BALRX7-Jet black  8944.0
# 239382  507562.0  canceled 2017-06-08       IDROID_BALRX7-Gold  8944.0
# 240078  508368.0  complete 2017-06-09       IDROID_BALRX7-Gold  8944.0
# 240079  508369.0  complete 2017-06-09  IDROID_BALRX7-Jet black  8944.0
#
#         qty_ordered  grand_total      category_name  discount_amount  \
# 239376       1000.0   17888000.0  Mobiles & Tablets              0.0
# 239377       1000.0   17888000.0  Mobiles & Tablets              0.0
# 239381       1000.0   17888000.0  Mobiles & Tablets              0.0
# 239382       1000.0   17888000.0  Mobiles & Tablets              0.0
# 240078       1000.0   17888000.0  Mobiles & Tablets              0.0
# 240079       1000.0   17888000.0  Mobiles & Tablets              0.0
#
#        payment_method working_date    year month customer_since customer_id
# 239376     jazzwallet   2017-06-08  2017.0   6.0         2016-8      5032.0
# 239377     jazzwallet   2017-06-08  2017.0   6.0         2016-8      5032.0
# 239381    jazzvoucher   2017-06-08  2017.0   6.0         2016-8      5032.0
# 239382    jazzvoucher   2017-06-08  2017.0   6.0         2016-8      5032.0
# 240078    jazzvoucher   2017-06-09  2017.0   6.0         2017-6     50387.0
# 240079    jazzvoucher   2017-06-09  2017.0   6.0         2017-6     50387.0

# %%
plt.figure(figsize=(16,3))
sns.boxplot(data=pak_ecommerce_data, x='price')
# Out:
# <Axes: xlabel='price'>

# %%
plt.figure(figsize=(16,3))
sns.boxplot(data=pak_ecommerce_data, x='grand_total')
# Out:
# <Axes: xlabel='grand_total'>

# %% [markdown]
# These are true outliers so no need to remove them.

# %%
pak_ecommerce_data.head()
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete 2016-07-01
# 1  211133.0        canceled 2016-07-01
# 2  211134.0        canceled 2016-07-01
# 3  211135.0        complete 2016-07-01
# 4  211136.0  order_refunded 2016-07-01
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total      category_name  discount_amount payment_method  \
# 0       1950.0    Women's Fashion              0.0            cod
# 1        240.0  Beauty & Grooming              0.0            cod
# 2       2450.0    Women's Fashion              0.0            cod
# 3         60.0  Beauty & Grooming            300.0            cod
# 4       1110.0            Soghaat              0.0            cod
#
#   working_date    year month customer_since customer_id
# 0   2016-07-01  2016.0   7.0         2016-7         1.0
# 1   2016-07-01  2016.0   7.0         2016-7         2.0
# 2   2016-07-01  2016.0   7.0         2016-7         3.0
# 3   2016-07-01  2016.0   7.0         2016-7         4.0
# 4   2016-07-01  2016.0   7.0         2016-7         5.0

# %% [markdown]
# ### Now data is much cleaned and ready to use for analysis and visualizations.

# %% [markdown]
# # Functions made for plot customizations and style

# %%
def set_size_style(width, height, style):
    plt.figure(figsize=(width, height))
    sns.set_style(style)
    
def customize_plot(plot, title:str, xlabel:str,  ylabel:str, title_font:int, label_font:int):
    plot.set_title(title, fontsize = title_font, weight='bold')
    plot.set_xlabel(xlabel, fontsize = label_font, weight='bold')
    plot.set_ylabel(ylabel, fontsize = label_font, weight='bold')

# %% [markdown]
# # What is the best-selling product categories among Pakistani online shoppers?

# %%
pak_ecommerce_data['category_name'].value_counts()
# Out:
# category_name
# Mobiles & Tablets     115710
# Men's Fashion          92221
# Women's Fashion        59721
# Appliances             52413
# Superstore             43613
# Beauty & Grooming      41496
# Soghaat                34011
# Others                 29382
# Home & Living          26504
# Entertainment          26326
# Health & Sports        17502
# Kids & Baby            16494
# Computing              15933
# \N                      7850
# School & Education      3478
# Books                   1870
# Name: count, dtype: int64

# %%
# for lab,row in pak_ecommerce_data.iterrows():
#     if row['category_name'] == '\\N':
#         pak_ecommerce_data[lab,'category_name'] = 'Others'
        
pak_ecommerce_data['category_name'].replace('\\N','Others', inplace=True)

# %%
set_size_style(12,6,'darkgrid')

ax = sns.countplot(data=pak_ecommerce_data, x='category_name', palette='husl')

customize_plot(ax, 'All selling categories among Pakistani shoppers', 'Category', 'Items sold', 12, 10)

ax.tick_params('x', rotation=90)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6336\1163841371.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=pak_ecommerce_data, x='category_name', palette='husl')

# %% [markdown]
# - Mobiles and Tablets is the best selling category, along with Men and Women's Fashion and appliances.

# %% [markdown]
# # Sale trends of previous years, in which months there are high sales?

# %%
total_sales_each_day = pak_ecommerce_data.groupby('created_at')[['grand_total']].sum().reset_index()

# %%
set_size_style(16,5,'darkgrid')
ax = sns.lineplot(data=total_sales_each_day, x='created_at', y='grand_total' ,errorbar=None)
ax.set_yticks(range(0,160000000+1,20000000))
ax.set_yticklabels(['0M', '20M', '40M', '60M', '80M', '100M', '120M', '140M', '160M'])
customize_plot(ax, 'Sales trend (All time)', 'Date', 'Total sales',13,10)

plt.show()

# %% [markdown]
# - There are hikes especially at the end of years. Hike indicates a lot of sale, these are due to promotional and sales campaigns of different E-Commerce companies. Let's have a closer look at each year.

# %%
total_sales_each_day['year'] = total_sales_each_day['created_at'].dt.year
total_sales_each_day['month'] = total_sales_each_day['created_at'].dt.month

sale_trend_16 = total_sales_each_day[total_sales_each_day['year'] == 2016]
sale_trend_17 = total_sales_each_day[total_sales_each_day['year'] == 2017]
sale_trend_18 = total_sales_each_day[total_sales_each_day['year'] == 2018]

# %%
set_size_style(16,5,'darkgrid')
ax = sns.lineplot(data=sale_trend_16, x='created_at', y='grand_total', color='purple', markers=True)
ax.set_yticks(range(0,70000000+1,10000000))
ax.set_yticklabels(['0M', '10M', '20M', '30M', '40M', '50M', '60M', '70M'])
customize_plot(ax, 'Sales trend (2016)', 'Date', 'Total sales',13,10)

plt.show()

# %%
set_size_style(16,5,'darkgrid')
ax = sns.lineplot(data=sale_trend_17, x='created_at', y='grand_total', color='teal', markers=True)
ax.set_yticks(range(0,160000000+1,20000000))
ax.set_yticklabels(['0M', '20M', '40M', '60M', '80M', '100M', '120M', '140M', '160M'])
customize_plot(ax, 'Sales trend (2017)', 'Date', 'Total sales',13,10)

plt.show()

# %%
set_size_style(16,6,'darkgrid')
ax = sns.lineplot(data=sale_trend_18, x='created_at', y='grand_total', color='darkorange', markers=True)
ax.set_yticks(range(0,80000000+1,10000000))
ax.set_yticklabels(['0M', '10M', '20M', '30M', '40M', '50M', '60M', '70M', '80M'])
customize_plot(ax, 'Sales trend (2018)', 'Date', 'Total sales',13,10)

plt.show()

# %%
by_month = total_sales_each_day.groupby('month')[['grand_total']].sum().reset_index()
sns.barplot(data=by_month, x='month', y='grand_total')
# Out:
# <Axes: xlabel='month', ylabel='grand_total'>

# %% [markdown]
# # How does the choice of payment method (credit card, Easy-Paisa, Jazz-Cash,cash-on-delivery) influence the completion and satisfaction of e-commerce orders?

# %%
pak_ecommerce_data['status'].value_counts()
# Out:
# status
# complete          233685
# canceled          201249
# received           77290
# order_refunded     59529
# refund              8050
# cod                 2859
# paid                1159
# closed               494
# payment_review        57
# pending               48
# processing            33
# holded                31
# fraud                 10
# pending_paypal         7
# exchange               4
# \N                     4
# Name: count, dtype: int64

# %%
pak_ecommerce_data['status'].replace(['received', 'cod', 'paid'],'complete', inplace=True)

pak_ecommerce_data['status'].replace('order_refunded', 'refund', inplace=True)

pak_ecommerce_data['status'].replace('closed', 'canceled', inplace=True)

pak_ecommerce_data['status'].replace(['payment_review', 'pending', 'processing', 'holded', 'fraud',
                                      'pending_paypal', 'exchange', '\\N'], 'others', inplace=True)

# %%
pak_ecommerce_data['status'].value_counts()
# Out:
# status
# complete    314993
# canceled    201743
# refund       67579
# others         194
# Name: count, dtype: int64

# %%
pak_ecommerce_data['payment_method'].value_counts()
# Out:
# payment_method
# cod                  271960
# Payaxis               97641
# Easypay               82900
# jazzwallet            35145
# easypay_voucher       31176
# bankalfalah           23065
# jazzvoucher           15633
# Easypay_MA            14028
# customercredit         7555
# apg                    1758
# ublcreditcard           882
# cashatdoorstep          732
# mcblite                 723
# mygateway               669
# internetbanking         472
# productcredit           125
# marketingexpense         45
# financesettlement        15
# Name: count, dtype: int64

# %%
pak_ecommerce_data['payment_method'].replace(['Payaxis', 'Easypay', 'jazzwallet', 'Easypay_MA', 'internetbanking',
                                              'mcblite', 'ublcreditcard', 'bankalfalah'], 'Mobile Wallets & Banks', inplace=True)

pak_ecommerce_data['payment_method'].replace(['easypay_voucher', 'jazzvoucher'], 'Vouchers', inplace=True)

pak_ecommerce_data['payment_method'].replace(['cashatdoorstep', 'cod'], 'Cash on Delivery', inplace=True)

pak_ecommerce_data['payment_method'].replace(['customercredit', 'apg', 'mygateway', 'productcredit',
                                              'marketingexpense', 'financesettlement'], 'Others', inplace=True)

# %%
pak_ecommerce_data['payment_method'].value_counts()
# Out:
# payment_method
# Cash on Delivery          272692
# Mobile Wallets & Banks    254856
# Vouchers                   46809
# Others                     10167
# Name: count, dtype: int64

# %%
set_size_style(7,5,'whitegrid')
ax = sns.countplot(data=pak_ecommerce_data, x='payment_method', edgecolor = 'k')
customize_plot(ax,'Payment methods count', 'Method', 'Count', 12,10)

# %%
ax = sns.countplot(data=pak_ecommerce_data, x='status', edgecolor='k')
customize_plot(ax,'Orders status', 'Status', 'Count', 12,10)
